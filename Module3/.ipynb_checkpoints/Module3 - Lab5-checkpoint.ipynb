# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab5

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# This is new
from pandas.tools.plotting import parallel_coordinates
from pandas.tools.plotting iport andrews_curves

plt.style.use('ggplot')

my_dataset = pd.read_csv("Datasets/wheat.data", index_col=0)

# %%
# Parallel Coordinates Start Here:
plt.figure()
parallel_coordinates(my_dataset, 'wheat_type', alpha=.1)
plt.show()

# %%
my_dataset.plot.scatter(x='compactness', y='width')

# Display the graphs:
plt.show()

# %%
# Andrews Curves Start Here:
plt.figure()
andrews_curves(my_dataframe, 'wheat_type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3a81f6847c59> in <module>()
#       1 # Andrews Curves Start Here:
#       2 plt.figure()
# ----> 3 andrews_curves(my_dataframe, 'wheat_type')
#       4 plt.show()
#
# NameError: name 'andrews_curves' is not defined
